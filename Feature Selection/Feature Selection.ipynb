# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

# %%
data=pd.read_csv('/home/girish/Downloads/train.csv')

# %%
data.head(5)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
data.shape
# Out:
# (2000, 21)

# %% [markdown]
# ## Seperating Target Value And Features

# %%
X=data.iloc[:,:20]
y=data.iloc[:,-1]

# %%
X.head(5)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %%
y.head(5)
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %%
y=pd.DataFrame(y)

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
y.head(2)
# Out:
#    price_range
# 0            1
# 1            2

# %% [markdown]
# # Feature Selection using chi2

# %%
best_features = SelectKBest(score_func=chi2,k=10)

# %%
fit = best_features.fit(X,y)

# %%
fit.scores_
# Out:
# array([1.41298666e+04, 7.23232323e-01, 6.48365906e-01, 6.31010795e-01,
#        1.01351665e+01, 1.52157239e+00, 8.98391244e+01, 7.45819631e-01,
#        9.59728626e+01, 9.09755558e+00, 9.18605355e+00, 1.73635695e+04,
#        9.81058675e+03, 9.31267519e+05, 9.61487832e+00, 1.64803191e+01,
#        1.32364000e+01, 3.27642810e-01, 1.92842942e+00, 4.22090730e-01])

# %%
fitData=pd.DataFrame(fit.scores_)

# %%
fitData.columns = ['Score']
fitData.sort_values('Score',ascending=False)
# Out:
#             Score
# 13  931267.519053
# 11   17363.569536
# 0    14129.866576
# 12    9810.586750
# 8       95.972863
# 6       89.839124
# 15      16.480319
# 16      13.236400
# 4       10.135166
# 14       9.614878
# 10       9.186054
# 9        9.097556
# 18       1.928429
# 5        1.521572
# 7        0.745820
# 1        0.723232
# 2        0.648366
# 3        0.631011
# 19       0.422091
# 17       0.327643

# %%
X.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi'],
#       dtype='object')

# %%
Xcolumns=pd.DataFrame(X.columns)

# %%
Xcolumns
# Out:
#                 0
# 0   battery_power
# 1            blue
# 2     clock_speed
# 3        dual_sim
# 4              fc
# 5          four_g
# 6      int_memory
# 7           m_dep
# 8       mobile_wt
# 9         n_cores
# 10             pc
# 11      px_height
# 12       px_width
# 13            ram
# 14           sc_h
# 15           sc_w
# 16      talk_time
# 17        three_g
# 18   touch_screen
# 19           wifi

# %%
featureScore=pd.concat([Xcolumns,fitData],axis=1)

# %%
featureScore.columns=['features','Score']

# %%
ten_features = featureScore.sort_values(by='Score',ascending=False).head(10)['features'].values

# %%
ten_features
# Out:
# array(['ram', 'px_height', 'battery_power', 'px_width', 'mobile_wt',
#        'int_memory', 'sc_w', 'talk_time', 'fc', 'sc_h'], dtype=object)

# %% [markdown]
# # Feature Importance
# ### Tree based Method

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier()

# %%
model.fit(X,y)
# Out:
# /tmp/ipykernel_23584/1298606489.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X,y)
# RandomForestClassifier()

# %%
model.feature_importances_
# Out:
# array([0.07440142, 0.00601235, 0.02793501, 0.00633887, 0.02411503,
#        0.00719359, 0.03479485, 0.02356897, 0.03674158, 0.0225766 ,
#        0.02887795, 0.05474023, 0.05620939, 0.49660709, 0.02667599,
#        0.02691053, 0.02845027, 0.00495167, 0.00685085, 0.00604777])

# %%
feature_Importance_Data=pd.DataFrame(model.feature_importances_ ,index=X.columns,columns=['Importance'])

# %%
feature_Importance_Data=feature_Importance_Data.sort_values(by='Importance',ascending=False)

# %%
plt.figure(figsize=(20,10))
plt.bar(feature_Importance_Data.index,feature_Importance_Data['Importance'])
plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
data_corr = data.corr()

# %%
data_corr
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data_corr,annot=True)
plt.show()

# %% [markdown]
# # Check the model performance

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
rfc = RandomForestClassifier()

# %%
scores = cross_val_score(rfc,X,y,cv=10)
# Out:
# /home/girish/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/girish/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/girish/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
scores.mean()
# Out:
# 0.875

# %%
X[ten_features]
# Out:
#        ram  px_height  battery_power  px_width  mobile_wt  int_memory  sc_w  \
# 0     2549         20            842       756        188           7     7
# 1     2631        905           1021      1988        136          53     3
# 2     2603       1263            563      1716        145          41     2
# 3     2769       1216            615      1786        131          10     8
# 4     1411       1208           1821      1212        141          44     2
# ...    ...        ...            ...       ...        ...         ...   ...
# 1995   668       1222            794      1890        106           2     4
# 1996  2032        915           1965      1965        187          39    10
# 1997  3057        868           1911      1632        108          36     1
# 1998   869        336           1512       670        145          46    10
# 1999  3919        483            510       754        168          45     4
#
#       talk_time  fc  sc_h
# 0            19   1     9
# ...

# %%
new_scores=cross_val_score(rfc,X[ten_features],y,cv=10)
# Out:
# /home/girish/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/girish/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/girish/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
new_scores.mean()
# Out:
# 0.9035
