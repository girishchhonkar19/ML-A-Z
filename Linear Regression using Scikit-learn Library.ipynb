# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_regression

# %%
X,y = make_regression(n_samples=1000,n_features=2,n_informative=1,noise =10,random_state=1)

# %%
print(X.shape,y.shape)
# Out:
# (1000, 2) (1000,)

# %%
plt.subplot(1,2,1)
plt.scatter(X[:,0],y)
plt.subplot(1,2,2)
plt.scatter(X[:,1],y)

# %%
# %matplotlib notebook

# %%
from mpl_toolkits import mplot3d

fig=plt.figure(figsize=(7,5))
axes=fig.gca(projection='3d')
axes.scatter3D(X[:,0],X[:,1],y,color='green')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
# /tmp/ipykernel_13316/1517650805.py:4: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   axes=fig.gca(projection='3d')

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([87.64399715,  0.19506063])

# %%
model.intercept_
# Out:
# 0.0538714877925921

# %%
model.predict([X[0],X[1]])
# Out:
# array([-128.13010102,  -68.56133458])

# %%
y[0], y[1]
# Out:
# (-129.49142895712546, -72.90042033913113)

# %%
model.score(X,y)
# Out:
# 0.9876578548379635
